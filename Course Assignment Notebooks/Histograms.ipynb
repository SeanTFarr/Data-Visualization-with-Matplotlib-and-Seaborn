# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
diamonds = (
    pd.read_csv("../data/Diamonds Prices2022.csv",
                low_memory=False,
               )
    .drop(["Unnamed: 0"], axis=1)
)

diamonds.head()
# Out:
#   carat      cut color clarity depth table price     x     y     z
# 0  0.23    Ideal     E     SI2  61.5    55   326  3.95  3.98  2.43
# 1  0.21  Premium     E     SI1  59.8    61   326  3.89  3.84  2.31
# 2  0.23     Good     E     VS1  56.9    65   327  4.05  4.07  2.31
# 3  0.29  Premium     I     VS2  62.4    58   334   4.2  4.23  2.63
# 4  0.31     Good     J     SI2  63.3    58   335  4.34  4.35  2.75

# %%
# it kept showing "TypeError: 'value' must be an instance of str or bytes, not a float"
#  though still an object
diamonds.carat = diamonds.carat.astype(str)

# %%
diamonds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107889 entries, 0 to 107888
# Data columns (total 10 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   carat    107889 non-null  object
#  1   cut      107887 non-null  object
#  2   color    107887 non-null  object
#  3   clarity  107887 non-null  object
#  4   depth    107887 non-null  object
#  5   table    107887 non-null  object
#  6   price    107887 non-null  object
#  7   x        107887 non-null  object
#  8   y        107887 non-null  object
#  9   z        107887 non-null  object
# dtypes: object(10)
# memory usage: 8.2+ MB

# %%
diamonds.sample(10)
# Out:
#       carat        cut color clarity depth table  price     x     y     z
# 5382   0.34    Premium     G     SI2  62.8    59    574  4.47  4.45   2.8
# 3431    0.9    Premium     I     VS2  59.1    59   3385  6.28  6.24   3.7
# 72937  1.14      Ideal     F     VS2  61.9    57   7819  6.67   6.7  4.13
# 21062   1.5    Premium     J     VS1  62.8    59   9240  7.29  7.19  4.55
# 75823  1.52      Ideal     F     SI2  61.9    57   9948  7.33  7.37  4.55
# 15178  1.01    Premium     F     VS2  62.7    58   6097   6.4  6.39  4.01
# 15355  1.28    Premium     I     SI1    60    60   6164  7.08  6.99  4.22
# 77367  1.57    Premium     H     VS2  62.2    58  11415  7.45   7.4  4.62
# 47992  0.32  Very Good     F     SI1  59.3    58    533  4.47   4.5  2.66
# 43892   0.3      Ideal     D     SI1  61.8    56    508  4.31  4.33  2.67

# %%
fig,ax = plt.subplots()

ax.hist(diamonds["carat"],
        bins=10,
        #density=True,
        edgecolor='white',
        linewidth=2,
)

plt.show()

# %%
fig,ax = plt.subplots()

ax.hist(diamonds.loc[diamonds["cut"]=="Ideal",["carat"]],
        bins=20,
        density=True,
        edgecolor='white',
        linewidth=2,
        alpha=.3
)

ax.hist(diamonds.loc[diamonds["cut"]=="Fair",["carat"]],
        bins=20,
        density=True,
        edgecolor='white',
        linewidth=2,
        alpha=.3
)

ax.legend(["Ideal","Fair"])

plt.show()
