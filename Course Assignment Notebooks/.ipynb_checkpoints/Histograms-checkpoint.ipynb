# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
diamonds = (
    pd.read_csv("../data/Diamonds Prices2022.csv",
                low_memory=False,
               )
    .drop(["Unnamed: 0"], axis=1)
)

diamonds.head()
# Out:
#   carat      cut color clarity depth table price     x     y     z
# 0  0.23    Ideal     E     SI2  61.5    55   326  3.95  3.98  2.43
# 1  0.21  Premium     E     SI1  59.8    61   326  3.89  3.84  2.31
# 2  0.23     Good     E     VS1  56.9    65   327  4.05  4.07  2.31
# 3  0.29  Premium     I     VS2  62.4    58   334   4.2  4.23  2.63
# 4  0.31     Good     J     SI2  63.3    58   335  4.34  4.35  2.75

# %%
diamonds.dtypes
# Out:
# carat      object
# cut        object
# color      object
# clarity    object
# depth      object
# table      object
# price      object
# x          object
# y          object
# z          object
# dtype: object

# %%
# it kept showing "TypeError: 'value' must be an instance of str or bytes, not a float"
#  though still an object
diamonds.carat = diamonds.carat.astype(str)

# %%
diamonds.dtypes
# Out:
# carat      object
# cut        object
# color      object
# clarity    object
# depth      object
# table      object
# price      object
# x          object
# y          object
# z          object
# dtype: object

# %%
diamonds.sample(10)
# Out:
#       carat        cut color clarity depth table  price     x     y     z
# 86003  0.33    Premium     I    VVS1  61.7    61    780  4.45  4.43  2.74
# 71065  1.02  Very Good     D     VS2  63.7    55   6830  6.42  6.45   4.1
# 11458  1.14    Premium     F     SI2  60.8    58   5008  6.79  6.74  4.11
# 29057   0.4       Good     E     SI1  63.5    57    687   4.7  4.72  2.99
# 90113  0.32      Ideal     F      IF  60.9    57    929   4.4  4.44  2.69
# 66303  1.01      Ideal     I     VS1  60.3    57   5231  6.51  6.53  3.93
# 80941  1.93    Premium     H     VS1  60.5    60  17096  8.06  7.98  4.85
# 13315  1.07    Premium     H     VS2  62.4    59   5498  6.53  6.46  4.05
# 16142  1.28    Premium     I     VS2  62.5    61   6451  6.89  6.86   4.3
# 92326  0.42    Premium     E     VS2    61    60   1024  4.85  4.82  2.95

# %%
fig,ax = plt.subplots()

ax.hist(diamonds["carat"],
        bins=10,
        density=True,
        edgecolor='white',
        linewidth=2,
)

plt.show()

# %%
fig,ax = plt.subplots()

ax.hist(diamonds.loc[diamonds["cut"]=="Ideal",["carat"]],
        bins=20,
        density=True,
        edgecolor='white',
        linewidth=2,
        alpha=.3
)

ax.hist(diamonds.loc[diamonds["cut"]=="Fair",["carat"]],
        bins=20,
        density=True,
        edgecolor='white',
        linewidth=2,
        alpha=.3
)

ax.legend(["Ideal","Fair"])

plt.show()
